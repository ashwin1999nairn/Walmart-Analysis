# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
train_df=pd.read_csv(r"D:\\ML Data\\walmart_train.csv")
test_df=pd.read_csv(r"D:\\ML Data\\walmart_test.csv")
features_df=pd.read_csv(r"D:\\ML Data\\walmart_features.csv")
stores_df=pd.read_csv(r"D:\\ML Data\\walmart_stores.csv")

# %%
train_df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
train_df.sample(10)
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 359535     38    85  2010-08-27         30.80      False
# 161872     17    33  2010-08-06       7545.93      False
# 220811     23    30  2010-04-09      10163.79      False
# 29716       4     2  2011-02-25     100464.89      False
# 356423     38    23  2012-02-17         34.55      False
# 241705     25    35  2010-09-10       2960.00       True
# 192091     20    35  2012-04-13       6562.67      False
# 392911     42    14  2012-08-17       1515.32      False
# 403718     43    91  2012-01-20      33485.52      False
# 27824       3    74  2012-09-07       3055.25       True

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
train_df.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
train_df.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %%
test_df.head()
# Out:
#    Store  Dept        Date  IsHoliday
# 0      1     1  2012-11-02      False
# 1      1     1  2012-11-09      False
# 2      1     1  2012-11-16      False
# 3      1     1  2012-11-23       True
# 4      1     1  2012-11-30      False

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115064 entries, 0 to 115063
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Store      115064 non-null  int64
#  1   Dept       115064 non-null  int64
#  2   Date       115064 non-null  object
#  3   IsHoliday  115064 non-null  bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 2.7+ MB

# %%
test_df.describe()
# Out:
#                Store           Dept
# count  115064.000000  115064.000000
# mean       22.238207      44.339524
# std        12.809930      30.656410
# min         1.000000       1.000000
# 25%        11.000000      18.000000
# 50%        22.000000      37.000000
# 75%        33.000000      74.000000
# max        45.000000      99.000000

# %%
test_df.isnull().sum()
# Out:
# Store        0
# Dept         0
# Date         0
# IsHoliday    0
# dtype: int64

# %%
features_df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
features_df.describe()
# Out:
#              Store  Temperature   Fuel_Price      MarkDown1      MarkDown2  \
# count  8190.000000  8190.000000  8190.000000    4032.000000    2921.000000
# mean     23.000000    59.356198     3.405992    7032.371786    3384.176594
# std      12.987966    18.678607     0.431337    9262.747448    8793.583016
# min       1.000000    -7.290000     2.472000   -2781.450000    -265.760000
# 25%      12.000000    45.902500     3.041000    1577.532500      68.880000
# 50%      23.000000    60.710000     3.513000    4743.580000     364.570000
# 75%      34.000000    73.880000     3.743000    8923.310000    2153.350000
# max      45.000000   101.950000     4.468000  103184.980000  104519.540000
#
#            MarkDown3     MarkDown4      MarkDown5          CPI  Unemployment
# count    3613.000000   3464.000000    4050.000000  7605.000000   7605.000000
# mean     1760.100180   3292.935886    4132.216422   172.460809      7.826821
# std     11276.462208   6792.329861   13086.690278    39.738346      1.877259
# min      -179.260000      0.220000    -185.170000   126.064000      3.684000
# 25%         6.600000    304.687500    1440.827500   132.364839      6.634000
# 50%        36.260000   1176.425000    2727.135000   182.764003      7.806000
# 75%       163.150000   3310.007500    4832.555000   213.932412      8.567000
# max    149483.310000  67474.850000  771448.100000   228.976456     14.313000

# %%
features_df.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
stores_df.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
stores_df.describe()
# Out:
#            Store           Size
# count  45.000000      45.000000
# mean   23.000000  130287.600000
# std    13.133926   63825.271991
# min     1.000000   34875.000000
# 25%    12.000000   70713.000000
# 50%    23.000000  126512.000000
# 75%    34.000000  202307.000000
# max    45.000000  219622.000000

# %%
stores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %%
stores_df.isnull().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
dataset_m=features_df.merge(stores_df, how='inner',on='Store')
dataset_m.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday Type  \
# 0        NaN        NaN        NaN  211.096358         8.106      False    A
# 1        NaN        NaN        NaN  211.242170         8.106       True    A
# 2        NaN        NaN        NaN  211.289143         8.106      False    A
# 3        NaN        NaN        NaN  211.319643         8.106      False    A
# 4        NaN        NaN        NaN  211.350143         8.106      False    A
#
#      Size
# 0  151315
# 1  151315
# 2  151315
# 3  151315
# 4  151315

# %%
dataset_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8190 entries, 0 to 8189
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
#  12  Type          8190 non-null   object
#  13  Size          8190 non-null   int64
# dtypes: bool(1), float64(9), int64(2), object(2)
# memory usage: 903.8+ KB

# %%
from datetime import datetime
# converting date to datetime
dataset_m['Date']=pd.to_datetime(dataset_m['Date'])
train_df['Date']=pd.to_datetime(train_df['Date'])
test_df['Date']=pd.to_datetime(test_df['Date'])

# %%
## Extract week and year from the date nd make them into new columns
dataset_m['week']=dataset_m.Date.dt.isocalendar().week
dataset_m['year']=dataset_m.Date.dt.isocalendar().year

# %%
dataset_m.tail()
# Out:
#       Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 8185     45 2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45 2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45 2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45 2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45 2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5  CPI  Unemployment  IsHoliday Type  \
# 8185       3.00    2449.97    3169.69  NaN           NaN      False    B
# 8186     582.74    5797.47    1514.93  NaN           NaN      False    B
# 8187      85.72     744.84    2150.36  NaN           NaN      False    B
# 8188     204.19     363.00    1059.46  NaN           NaN      False    B
# 8189       2.06      10.88    1864.57  NaN           NaN      False    B
#
#         Size  week  year
# 8185  118221    26  2013
# 8186  118221    27  2013
# 8187  118221    28  2013
# 8188  118221    29  2013
# 8189  118221    30  2013

# %%
## Creating a new df by merging (inner) the train_df and the new dataframe dataset_m on store, data and isholiday columns and sorting the values by store, department and date

# %%
train_df_1=train_df.merge(dataset_m, how='inner', on=['Store', 'Date', 'IsHoliday']).sort_values(by=['Store', 'Dept', 'Date']).reset_index(drop=True)

# %%
train_df_1.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50      False        42.31       2.572
# 1      1     1 2010-02-12      46039.49       True        38.51       2.548
# 2      1     1 2010-02-19      41595.55      False        39.93       2.514
# 3      1     1 2010-02-26      19403.54      False        46.63       2.561
# 4      1     1 2010-03-05      21827.90      False        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.242170
# 2        NaN        NaN        NaN        NaN        NaN  211.289143
# 3        NaN        NaN        NaN        NaN        NaN  211.319643
# 4        NaN        NaN        NaN        NaN        NaN  211.350143
#
#    Unemployment Type    Size  week  year
# 0         8.106    A  151315     5  2010
# 1         8.106    A  151315     6  2010
# 2         8.106    A  151315     7  2010
# 3         8.106    A  151315     8  2010
# 4         8.106    A  151315     9  2010

# %% [markdown]
# Visualizations

# %% [markdown]
# 1. Scatter Plots

# %%
def scatter(train_df_1, column):
    plt.figure()
    plt.scatter(train_df_1[column], train_df_1['Weekly_Sales'])
    plt.ylabel("Weekly Sales")
    plt.xlabel(column)

# %%
scatter(train_df_1, 'Store')

# %%
scatter(train_df_1, 'Dept')

# %% [markdown]
# 2) line plots for weekly sales for each year

# %%
weekly_sales_2011=train_df_1[train_df_1['year']==2011]['Weekly_Sales'].groupby(train_df_1['week']).mean()
sns.lineplot(weekly_sales_2011.index, weekly_sales_2011.values, color='red')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='week'>

# %%
weekly_sales_2010=train_df_1[train_df_1['year']==2010]['Weekly_Sales'].groupby(train_df_1['week']).mean()
sns.lineplot(weekly_sales_2010.index, weekly_sales_2010.values, color='blue')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='week'>

# %%
weekly_sales_2012=train_df_1[train_df_1['year']==2012]['Weekly_Sales'].groupby(train_df_1['week']).mean()
sns.lineplot(weekly_sales_2012.index, weekly_sales_2012.values, color='green')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='week'>

# %% [markdown]
# Combined lineplots for the years 2010,2011,2012 and plotting their weekly sales

# %%
plt.figure(figsize=(20,10))
sns.lineplot(weekly_sales_2010.index, weekly_sales_2010.values, color='blue')
sns.lineplot(weekly_sales_2011.index, weekly_sales_2011.values, color='red')
sns.lineplot(weekly_sales_2012.index, weekly_sales_2012.values, color='green')
plt.grid()
plt.title("Average Weekly Sales per year", fontsize=20)
plt.xticks(np.arange(1,60,step=1))
plt.xlabel("week", fontsize=16)
plt.ylabel("sales", fontsize=16)
plt.legend(['2010', '2011', '2012'], fontsize=16)
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Histogram

# %%
sns.distplot(train_df_1['Weekly_Sales'], color='g')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weekly_Sales', ylabel='Density'>

# %%
## Kutosis is a measure of whether data is heavy-tailed or light-tailed relative to normal distribution
train_df_1.kurt()
# Out:
# C:\Users\Ashwin\AppData\Local\Temp/ipykernel_18556/2919759450.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   train_df_1.kurt()
# Store            -1.146503
# Dept             -1.215571
# Weekly_Sales     21.491290
# IsHoliday         9.288747
# Temperature      -0.635922
# Fuel_Price       -1.185405
# MarkDown1        17.606263
# MarkDown2        37.589561
# MarkDown3        77.687772
# MarkDown4        29.996815
# MarkDown5       107.849266
# CPI              -1.829714
# Unemployment      2.731217
# Size             -1.206346
# week             -1.111679
# year             -1.423235
# dtype: float64

# %%
train_df_1['Weekly_Sales'].kurt()
# Out:
# 21.49128990832619

# %% [markdown]
# 6) Bar Chart on DataFrame

# %%
weekly_sales_store=train_df_1['Weekly_Sales'].groupby(train_df_1['Store']).mean()

# %%
weekly_sales_store.head()
# Out:
# Store
# 1    21710.543621
# 2    26898.070031
# 3     6373.033983
# 4    29161.210415
# 5     5053.415813
# Name: Weekly_Sales, dtype: float64

# %%
weekly_sales_store_df=pd.DataFrame(weekly_sales_store)

# %%
weekly_sales_store_df.sort_values('Weekly_Sales', ascending=False).style.bar(align='left', width=98)
# Out:
# <style type="text/css">
# #T_a1646_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 98.0%, transparent 98.0%);
# }
# #T_a1646_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 96.6%, transparent 96.6%);
# }
# #T_a1646_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 95.1%, transparent 95.1%);
# }
# #T_a1646_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 89.4%, transparent 89.4%);
# }
# #T_a1646_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 87.5%, transparent 87.5%);
# }
# #T_a1646_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 85.3%, transparent 85.3%);
# }
# #T_a1646_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 79.2%, transparent 79.2%);
# }
# #T_a1646_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 67.6%, transparent 67.6%);
# }
# #T_a1646_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 66.8%, transparent 66.8%);
# }
# #T_a1646_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 63.9%, transparent 63.9%);
# }
# #T_a1646_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 61.3%, transparent 61.3%);
# }
# #T_a1646_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 59.0%, transparent 59.0%);
# }
# #T_a1646_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 58.6%, transparent 58.6%);
# }
# #T_a1646_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 57.0%, transparent 57.0%);
# }
# #T_a1646_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 55.8%, transparent 55.8%);
# }
# #T_a1646_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 54.7%, transparent 54.7%);
# }
# #T_a1646_row16_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 51.8%, transparent 51.8%);
# }
# #T_a1646_row17_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 45.3%, transparent 45.3%);
# }
# #T_a1646_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 42.8%, transparent 42.8%);
# }
# #T_a1646_row19_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 40.6%, transparent 40.6%);
# }
# #T_a1646_row20_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 39.3%, transparent 39.3%);
# }
# #T_a1646_row21_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 38.1%, transparent 38.1%);
# }
# #T_a1646_row22_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 35.1%, transparent 35.1%);
# }
# #T_a1646_row23_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 34.9%, transparent 34.9%);
# }
# #T_a1646_row24_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 33.9%, transparent 33.9%);
# }
# #T_a1646_row25_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 33.5%, transparent 33.5%);
# }
# #T_a1646_row26_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 32.4%, transparent 32.4%);
# }
# #T_a1646_row27_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 31.7%, transparent 31.7%);
# }
# #T_a1646_row28_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 26.5%, transparent 26.5%);
# }
# #T_a1646_row29_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.6%, transparent 25.6%);
# }
# #T_a1646_row30_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.0%, transparent 25.0%);
# }
# #T_a1646_row31_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.1%, transparent 21.1%);
# }
# #T_a1646_row32_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.0%, transparent 21.0%);
# }
# #T_a1646_row33_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 15.8%, transparent 15.8%);
# }
# #T_a1646_row34_col0, #T_a1646_row35_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 14.9%, transparent 14.9%);
# }
# #T_a1646_row36_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 14.2%, transparent 14.2%);
# }
# #T_a1646_row37_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 13.2%, transparent 13.2%);
# }
# #T_a1646_row38_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 12.4%, transparent 12.4%);
# }
# #T_a1646_row39_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 11.3%, transparent 11.3%);
# }
# #T_a1646_row40_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 9.8%, transparent 9.8%);
# }
# #T_a1646_row41_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.3%, transparent 5.3%);
# }
# #T_a1646_row42_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 3.9%, transparent 3.9%);
# }
# #T_a1646_row43_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.7%, transparent 2.7%);
# }
# #T_a1646_row44_col0 {
#   width: 10em;
#   height: 80%;
# }
# </style>
# <table id="T_a1646_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Weekly_Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Store</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1646_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_a1646_row0_col0" class="data row0 col0" >29508.301592</td>
#     </tr>
#     <tr>
#       <th id="T_a1646_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_a1646_row1_col0" class="data row1 col0" >29161.210415</td>
#     </tr>
#     <tr>
#       <th id="T_a1646_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_a1646_row2_col0" class="data row2 col0" >28784.851727</td>
#     </tr>
#     <tr>
#       <th id="T_a1646_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_a1646_row3_col0" class="data row3 col0" >27355.136891</td>
#     </tr>
#     <tr>
#       <th id="T_a1646_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_a1646_row4_col0" class="data row4 col0" >26898.070031</td>
#     </tr>
#     <tr>
#       <th id="T_a1646_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_a1646_row5_col0" class="data row5 col0" >26332.303819</td>
#     </tr>
#     <tr>
#       <th id="T_a1646_level0_row6" class="row_heading level0 row6" >27</th>
#       <td id="T_a1646_row6_col0" class="data row6 col0" >24826.984536</td>
#     </tr>
#     <tr>
#       <th id="T_a1646_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_a1646_row7_col0" class="data row7 col0" >21913.243624</td>
#     </tr>
#     <tr>
#       <th id="T_a1646_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_a1646_row8_col0" class="data row8 col0" >21710.543621</td>
#     </tr>
#     <tr>
#       <th id="T_a1646_level0_row9" class="row_heading level0 row9" >39</th>
#       <td id="T_a1646_row9_col0" class="data row9 col0" >21000.763562</td>
#     </tr>
#     <tr>
#       <th id="T_a1646_level0_row10" class="row_heading level0 row10" >19</th>
#       <td id="T_a1646_row10_col0" class="data row10 col0" >20362.126734</td>
#     </tr>
#     <tr>
#       <th id="T_a1646_level0_row11" class="row_heading level0 row11" >23</th>
#       <td id="T_a1646_row11_col0" class="data row11 col0" >19776.180881</td>
#     </tr>
#     <tr>
#       <th id="T_a1646_level0_row12" class="row_heading level0 row12" >31</th>
#       <td id="T_a1646_row12_col0" class="data row12 col0" >19681.907464</td>
#     </tr>
#     <tr>
#       <th id="T_a1646_

# %%
weekly_sales_store_df.sort_values('Weekly_Sales').style.bar(align='left', width=98)
# Out:
# <style type="text/css">
# #T_8f5cd_row0_col0 {
#   width: 10em;
#   height: 80%;
# }
# #T_8f5cd_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.7%, transparent 2.7%);
# }
# #T_8f5cd_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 3.9%, transparent 3.9%);
# }
# #T_8f5cd_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.3%, transparent 5.3%);
# }
# #T_8f5cd_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 9.8%, transparent 9.8%);
# }
# #T_8f5cd_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 11.3%, transparent 11.3%);
# }
# #T_8f5cd_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 12.4%, transparent 12.4%);
# }
# #T_8f5cd_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 13.2%, transparent 13.2%);
# }
# #T_8f5cd_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 14.2%, transparent 14.2%);
# }
# #T_8f5cd_row9_col0, #T_8f5cd_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 14.9%, transparent 14.9%);
# }
# #T_8f5cd_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 15.8%, transparent 15.8%);
# }
# #T_8f5cd_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.0%, transparent 21.0%);
# }
# #T_8f5cd_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.1%, transparent 21.1%);
# }
# #T_8f5cd_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.0%, transparent 25.0%);
# }
# #T_8f5cd_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.6%, transparent 25.6%);
# }
# #T_8f5cd_row16_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 26.5%, transparent 26.5%);
# }
# #T_8f5cd_row17_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 31.7%, transparent 31.7%);
# }
# #T_8f5cd_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 32.4%, transparent 32.4%);
# }
# #T_8f5cd_row19_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 33.5%, transparent 33.5%);
# }
# #T_8f5cd_row20_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 33.9%, transparent 33.9%);
# }
# #T_8f5cd_row21_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 34.9%, transparent 34.9%);
# }
# #T_8f5cd_row22_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 35.1%, transparent 35.1%);
# }
# #T_8f5cd_row23_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 38.1%, transparent 38.1%);
# }
# #T_8f5cd_row24_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 39.3%, transparent 39.3%);
# }
# #T_8f5cd_row25_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 40.6%, transparent 40.6%);
# }
# #T_8f5cd_row26_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 42.8%, transparent 42.8%);
# }
# #T_8f5cd_row27_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 45.3%, transparent 45.3%);
# }
# #T_8f5cd_row28_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 51.8%, transparent 51.8%);
# }
# #T_8f5cd_row29_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 54.7%, transparent 54.7%);
# }
# #T_8f5cd_row30_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 55.8%, transparent 55.8%);
# }
# #T_8f5cd_row31_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 57.0%, transparent 57.0%);
# }
# #T_8f5cd_row32_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 58.6%, transparent 58.6%);
# }
# #T_8f5cd_row33_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 59.0%, transparent 59.0%);
# }
# #T_8f5cd_row34_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 61.3%, transparent 61.3%);
# }
# #T_8f5cd_row35_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 63.9%, transparent 63.9%);
# }
# #T_8f5cd_row36_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 66.8%, transparent 66.8%);
# }
# #T_8f5cd_row37_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 67.6%, transparent 67.6%);
# }
# #T_8f5cd_row38_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 79.2%, transparent 79.2%);
# }
# #T_8f5cd_row39_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 85.3%, transparent 85.3%);
# }
# #T_8f5cd_row40_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 87.5%, transparent 87.5%);
# }
# #T_8f5cd_row41_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 89.4%, transparent 89.4%);
# }
# #T_8f5cd_row42_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 95.1%, transparent 95.1%);
# }
# #T_8f5cd_row43_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 96.6%, transparent 96.6%);
# }
# #T_8f5cd_row44_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 98.0%, transparent 98.0%);
# }
# </style>
# <table id="T_8f5cd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Weekly_Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Store</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f5cd_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_8f5cd_row0_col0" class="data row0 col0" >5053.415813</td>
#     </tr>
#     <tr>
#       <th id="T_8f5cd_level0_row1" class="row_heading level0 row1" >33</th>
#       <td id="T_8f5cd_row1_col0" class="data row1 col0" >5728.414053</td>
#     </tr>
#     <tr>
#       <th id="T_8f5cd_level0_row2" class="row_heading level0 row2" >44</th>
#       <td id="T_8f5cd_row2_col0" class="data row2 col0" >6038.929814</td>
#     </tr>
#     <tr>
#       <th id="T_8f5cd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8f5cd_row3_col0" class="data row3 col0" >6373.033983</td>
#     </tr>
#     <tr>
#       <th id="T_8f5cd_level0_row4" class="row_heading level0 row4" >38</th>
#       <td id="T_8f5cd_row4_col0" class="data row4 col0" >7492.478460</td>
#     </tr>
#     <tr>
#       <th id="T_8f5cd_level0_row5" class="row_heading level0 row5" >16</th>
#       <td id="T_8f5cd_row5_col0" class="data row5 col0" >7863.224124</td>
#     </tr>
#     <tr>
#       <th id="T_8f5cd_level0_row6" class="row_heading level0 row6" >29</th>
#       <td id="T_8f5cd_row6_col0" class="data row6 col0" >8158.810609</td>
#     </tr>
#     <tr>
#       <th id="T_8f5cd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8f5cd_row7_col0" class="data row7 col0" >8358.766148</td>
#     </tr>
#     <tr>
#       <th id="T_8f5cd_level0_row8" class="row_heading level0 row8" >36</th>
#       <td id="T_8f5cd_row8_col0" class="data row8 col0" >8584.412563</td>
#     </tr>
#     <tr>
#       <th id="T_8f5cd_level0_row9" class="row_heading level0 row9" >30</th>
#       <td id="T_8f5cd_row9_col0" class="data row9 col0" >8764.237719</td>
#     </tr>
#     <tr>
#       <th id="T_8f5cd_level0_row10" class="row_heading level0 row10" >9</th>
#       <td id="T_8f5cd_row10_col0" class="data row10 col0" >8772.890379</td>
#     </tr>
#     <tr>
#       <th id="T_8f5cd_level0_row11" class="row_heading level0 row11" >15</th>
#       <td id="T_8f5cd_row11_col0" class="data row11 col0" >9002.493073</td>
#     </tr>
#     <tr>
#       <th id="T_8f5cd_level0_row12" class="row_heading level0 row12" >37</th>
#       <td id="T_8f5cd_row12_col0" class="data row12 col0" >10297.355026</td>
#     </tr>
#     <tr>
#       <th id="T_8f5cd_level0_row13

# %% [markdown]
# Plotting a graph with store number as x values and mean weekly sales for that store as y values

# %%
## Plotting the figure
plt.figure(figsize=(25,12))
## create a bar plot with stores in x axis and mean weekly sales as y values
sns.barplot(weekly_sales_store.index, weekly_sales_store.values, palette='dark')
plt.grid()
plt.title('Average Weekly Sales per store', fontsize=20)
plt.xlabel("Store Number", fontsize=16)
plt.ylabel("Mean Weekly Sales", fontsize=16)
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Mean Weekly Sales')

# %% [markdown]
# Grouping the train_df_1 by department and comparing the mean of weekly_sales for each department

# %%
weekly_sales_dept=train_df_1['Weekly_Sales'].groupby(train_df_1['Dept']).mean()

# %%
weekly_sales_dept_df=pd.DataFrame(weekly_sales_dept)

# %%
weekly_sales_dept_df.head()
# Out:
#       Weekly_Sales
# Dept
# 1     19213.485088
# 2     43607.020113
# 3     11793.698516
# 4     25974.630238
# 5     21365.583515

# %%
# Sorting the DataFrame with respect to weekly sales in descending order
weekly_sales_dept_df.sort_values("Weekly_Sales", ascending=False).style.bar(align='left', width=98)
# Out:
# <style type="text/css">
# #T_61ec4_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 98.0%, transparent 98.0%);
# }
# #T_61ec4_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 91.0%, transparent 91.0%);
# }
# #T_61ec4_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 79.6%, transparent 79.6%);
# }
# #T_61ec4_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 65.9%, transparent 65.9%);
# }
# #T_61ec4_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 59.2%, transparent 59.2%);
# }
# #T_61ec4_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 58.9%, transparent 58.9%);
# }
# #T_61ec4_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 58.5%, transparent 58.5%);
# }
# #T_61ec4_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 56.8%, transparent 56.8%);
# }
# #T_61ec4_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 43.9%, transparent 43.9%);
# }
# #T_61ec4_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 43.5%, transparent 43.5%);
# }
# #T_61ec4_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 40.0%, transparent 40.0%);
# }
# #T_61ec4_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 39.3%, transparent 39.3%);
# }
# #T_61ec4_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 35.2%, transparent 35.2%);
# }
# #T_61ec4_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 33.9%, transparent 33.9%);
# }
# #T_61ec4_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 31.5%, transparent 31.5%);
# }
# #T_61ec4_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 31.2%, transparent 31.2%);
# }
# #T_61ec4_row16_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 28.6%, transparent 28.6%);
# }
# #T_61ec4_row17_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 27.8%, transparent 27.8%);
# }
# #T_61ec4_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 26.3%, transparent 26.3%);
# }
# #T_61ec4_row19_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 26.0%, transparent 26.0%);
# }
# #T_61ec4_row20_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.0%, transparent 25.0%);
# }
# #T_61ec4_row21_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 23.9%, transparent 23.9%);
# }
# #T_61ec4_row22_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 20.4%, transparent 20.4%);
# }
# #T_61ec4_row23_col0, #T_61ec4_row24_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 20.2%, transparent 20.2%);
# }
# #T_61ec4_row25_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 19.8%, transparent 19.8%);
# }
# #T_61ec4_row26_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 19.4%, transparent 19.4%);
# }
# #T_61ec4_row27_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 18.9%, transparent 18.9%);
# }
# #T_61ec4_row28_col0, #T_61ec4_row29_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 18.6%, transparent 18.6%);
# }
# #T_61ec4_row30_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 18.0%, transparent 18.0%);
# }
# #T_61ec4_row31_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 17.5%, transparent 17.5%);
# }
# #T_61ec4_row32_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 15.9%, transparent 15.9%);
# }
# #T_61ec4_row33_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 15.4%, transparent 15.4%);
# }
# #T_61ec4_row34_col0, #T_61ec4_row35_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 14.0%, transparent 14.0%);
# }
# #T_61ec4_row36_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 13.3%, transparent 13.3%);
# }
# #T_61ec4_row37_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 11.7%, transparent 11.7%);
# }
# #T_61ec4_row38_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 10.6%, transparent 10.6%);
# }
# #T_61ec4_row39_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 10.0%, transparent 10.0%);
# }
# #T_61ec4_row40_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 9.7%, transparent 9.7%);
# }
# #T_61ec4_row41_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 9.6%, transparent 9.6%);
# }
# #T_61ec4_row42_col0, #T_61ec4_row43_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 8.9%, transparent 8.9%);
# }
# #T_61ec4_row44_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 8.4%, transparent 8.4%);
# }
# #T_61ec4_row45_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 8.3%, transparent 8.3%);
# }
# #T_61ec4_row46_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 7.5%, transparent 7.5%);
# }
# #T_61ec4_row47_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 7.4%, transparent 7.4%);
# }
# #T_61ec4_row48_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 7.2%, transparent 7.2%);
# }
# #T_61ec4_row49_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 6.8%, transparent 6.8%);
# }
# #T_61ec4_row50_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 6.5%, transparent 6.5%);
# }
# #T_61ec4_row51_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 6.2%, transparent 6.2%);
# }
# #T_61ec4_row52_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 6.1%, transparent 6.1%);
# }
# #T_61ec4_row53_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.5%, transparent 5.5%);
# }
# #T_61ec4_row54_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.4%, transparent 5.4%);
# }
# #T_61ec4_row55_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.0%, transparent 5.0%);
# }
# #T_61ec4_row56_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 4.8%, transparent 4.8%);
# }
# #T_61ec4_row57_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 4.4%, transparent 4.4%);
# }
# #T_61ec4_row58_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 4.1%, transparent 4.1%);
# }
# #T_61ec4_row59_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 3.8%, transparent 3.8%);
# }
# #T_61ec4_row60_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 3.5%, transparent 3.5%);
# }
# #T_61ec4_row61_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 3.1%, transparent 3.1%);
# }
# #T_61ec4_row62_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 3.0%, transparent 3.0%);
# }
# #T_61ec4_row63_col0, #T_61ec4_row64_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.6%, transparent 2.6%);
# }
# #T_61ec4_row65_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.5%, transparent 2.5%);
# }
# #T_61ec4_row66_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
# }
# #T_61ec4_row67_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.1%, transparent 2.1%);
# }
# #T_61ec4_row68_col0 {
#   width: 10em;
#   height: 80%;
#   back

# %%
## plotting a figure
plt.figure(figsize=(25,12))
## create a bar plot with department in x axis and mean weekly sales for each department in y axis
sns.barplot(weekly_sales_dept.index, weekly_sales_dept.values)
plt.grid()
plt.title("Average Weekly Sales per Department", fontsize=20)
plt.xlabel("Department Number")
plt.ylabel("Average Weekly Sales")
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Average Weekly Sales')

# %%
## Plotting the normal distribution where sales is greater than 0
train_sales=train_df_1[train_df_1['Weekly_Sales']>0]
train_less_than_zero=train_df_1[train_df_1['Weekly_Sales']<=0]
# Take natural log of postive sales
sales_greater_than_zero=np.log1p(train_sales['Weekly_Sales'])
sns.distplot(sales_greater_than_zero)
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weekly_Sales', ylabel='Density'>

# %% [markdown]
# Heatmap

# %%
plt.figure(figsize=(25,15))
sns.heatmap(train_df_1.corr(), annot=True)
# Out:
# <AxesSubplot:>
